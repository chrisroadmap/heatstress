# %% [markdown]
# # Setting up the environment on JASMIN
#
# We need some additional python packages that are not part of the standard distribution of Jaspy. See https://github.com/cedadev/ceda-notebooks/blob/master/notebooks/docs/add_conda_envs.ipynb

# %%
# Create the conda environment
# !conda create -y --name heatstress
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/users/pmcjs/.conda/envs/heatstress
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate heatstress
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# Install the "ipykernel" library into the environment. This is required in order to make Jupyter aware of the environment.
# !conda install -y -n heatstress ipykernel
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/users/pmcjs/.conda/envs/heatstress
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            1_gnu          22 KB  conda-forge
#     backcall-0.2.0             |     pyh9f0ad1d_0          13 KB  conda-forge
#     backports-1.0              |             py_2           4 KB  conda-forge
#     backports.functools_lru_cache-1.6.4|     pyhd8ed1ab_0           9 KB  conda-forge
#     ca-certificates-2020.12.5  |       ha878542_0         137 KB  conda-forge
# ...

# %%
# Install the environment as an "ipykernel" so that the Notebook Service will find it.
# !conda run -n heatstress python -m ipykernel install --user --name heatstress
# Out:
# Installed kernelspec heatstress in /home/users/pmcjs/.local/share/jupyter/kernels/heatstress

# %%
# Install the climateforcing package
# !conda install -y -n heatstress -c chrisroadmap climateforcing
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/users/pmcjs/.conda/envs/heatstress
#
#   added / updated specs:
#     - climateforcing
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     c-ares-1.17.1              |       h7f98852_1         109 KB  conda-forge
#     cftime-1.4.1               |   py39hce5d2b2_0         326 KB  conda-forge
#     climateforcing-v0.2.1      |           py39_0          58 KB  chrisroadmap
#     curl-7.76.1                |       h979ede3_1         149 KB  conda-forge
#     hdf4-4.2.13                |    h10796ff_1005         949 KB  conda-forge
# ...

# %%
# Install iris 2.4 through conda-forge (we can't use iris 3 because they have downgraded cftime)
# !conda install -y -n heatstress -c conda-forge iris==2.4.0
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/users/pmcjs/.conda/envs/heatstress
#
#   added / updated specs:
#     - iris==2.4.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     antlr-python-runtime-4.7.2 |py39hf3d152e_1002         166 KB  conda-forge
#     bokeh-2.3.1                |   py39hf3d152e_0         8.2 MB  conda-forge
#     cartopy-0.19.0             |   py39h3b23250_0         1.8 MB  conda-forge
#     cf-units-2.1.4             |   py39h1dff97c_2         168 KB  conda-forge
#     click-7.1.2                |     pyh9f0ad1d_0          64 KB  conda-forge
# ...
